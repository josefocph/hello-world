# %%
# With model parameters in dictionary:
# %load_ext autoreload
# %autoreload
import numpy as np
a = np.array([1,2,3])
b = inauguralproject.square(a)
print (b)
mp ={'phi':0.3, 'epsl':0.5, 'rho':0.03, 'tau_g':0.012, 'tau_p':0.004, 'p_bar':3} # All parameters in dictionary

def utility(c,h,mp):
    return (c**(1-mp['phi']))*(h**mp['phi'])

# we can use either dictionary mp or global variables defined seperately down here
# With globals:
phi = 0.3
epsl = 0.05
rho = 0.03
tau_g = 0.012
tau_p = 0.004
p_bar = 3
N = 10000
np.random.seed(1986)

def utility(c,h,phi):
    return (c**(1-phi))*(h**phi)

def utility(c,h,mp):
    """ Calculates utility of chosen (consumption, housing) bundle.

    Args:

    c (float): consumption
    h (float): housing 
    mp (dict): model parameters. 

    Returns:

    (float): utility of bundle
    """
    return (c**(1-mp['phi']))*(h**mp['phi'])
# question 1
def square(x):
    """ square numpy array
    
    Args:
    
        x (ndarray): input array
        
    Returns:
    
        y (ndarray): output array
    
    """
    
    y = x**2
    return y

# %% [markdown]
# What about the taxes on housing,  𝜏(𝑝ℎ,𝑝̃ℎ)
#
# p_tilde = h**epsl
# because ph = h
#
# Note that when we define  𝑝ℎ=ℎ
# ph=h
#   it implies that  𝜏(⋅)
# τ(⋅)is a function of  ℎ
# and model parameters.
#
# When you define the model it can be wise to set  𝑝 numeraire.
#
# Find  𝑝̃ from eq.2 and calculate housing taxes. Mortgage costs not included here!
#
# 3.4 What's missing?
#
# Total cost of housing (taxes + interest)
# Optimal consumption given housing (and parameters...)
# Objective function. Hint: see lecture 3, section "Algorithm 3: Call a solver".
# Solver. Optimize  ℎ
# and find implied  𝑐,𝑢
